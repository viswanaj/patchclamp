# %% [markdown]
# # Patch Clamp Analysis Toolkit - Example Usage
#
# This notebook demonstrates how to use the consolidated patch clamp analysis toolkit.

# %%
# Import the main analysis functions
from patchclamp_analysis import (
    analyze_rmp, 
    analyze_holding_current_segmented,
    generate_event_tables_with_trace,
    plot_current_clamp_abf,
    plot_voltage_clamp_abf,
    analyze_current_voltage_relationship,
    plot_iv_curve
)

import numpy as np
import matplotlib.pyplot as plt
import os

# %%
# Plot membrane voltage vs time in minutes for your specific ABF file
from patchclamp_analysis import plot_membrane_voltage_vs_time_minutes

# Path to your ABF file
abf_file_path = "/Users/jayashri/Desktop/25323004.abf"

# Plot membrane voltage as a function of time in minutes
plot_membrane_voltage_vs_time_minutes(abf_file_path)
